# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Python套件管理

# %%
pip install numpy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
# ...

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 定義dataFrame

# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 6.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.1 MB 11.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.1 MB 8.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.2/11.1 MB 8.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.1 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 10.5 MB/s  0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
# ...

# %% [markdown]
# git 設定指令

# %%
# git config --global user.email "gtaped14876@gmail.com"
# git config --global user.name "jack-pig-liu"

# %%
import pandas as pd

# %% [markdown]
# dictionary 轉 dataframe

# %%
ohlc = {
    'open':[1,2,3,4],
    'close':[2,3,4,5]
}

pd.DataFrame(ohlc)
# Out:
#    open  close
# 0     1      2
# 1     2      3
# 2     3      4
# 3     4      5
